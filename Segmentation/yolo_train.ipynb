# %%
# !yolo task=segment mode=train model=yolo11s-seg.pt data=data.yaml epochs=150 imgsz=640 plots=True batch=16 iou=0.9 weight_decay=5.361517436276594e-06 lr0=3.9587075181243235e-05 lrf=0.001 weights=hyp.yaml
#Best hyperparameters: {'learning_rate': 3.9587075181243235e-05, 'batch_size': 8, 'weight_decay': 5.361517436276594e-06}
# Out:
# ^C

# %%
# To resume training
# !yolo task=detect mode=train resume model=/content/drive/MyDrive/yolov8/training_results/helmets5/weights/last.pt data=/content/drive/MyDrive/yolov8/dataset.yaml epochs=100 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=helmets

yolo export model=yolo11n.pt format=engine  # creates 'yolo11n.engine''

# Run inference with the exported model
yolo predict model=yolo11n.engine source='https://ultralytics.com/images/bus.jpg'

yolo detect val model=C:\Users\Spacelab3\Desktop\envs\Segmentation\best-InitParam_S_NoW_150.pt data="C:\Users\Spacelab3\Desktop\envs\InstanceSegmentationNew\data.yaml"
